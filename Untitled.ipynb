kB/s eta 0:00:02
#      ----------------------------------- -- 11.9/12.8 MB 840.4 kB/s eta 0:00:02
#      ----------------------------------- -- 11.9/12.8 MB 839.4 kB/s eta 0:00:02
#      ----------------------------------- -- 12.0/12.8 MB 835.1 kB/s eta 0:00:02
#      ----------------------------------- -- 12.0/12.8 MB 833.0 kB/s eta 0:00:01
#      ----------------------------------- -- 12.1/12.8 MB 829.8 kB/s eta 0:00:01
#      ----------------------------------- -- 12.1/12.8 MB 826.6 kB/s eta 0:00:01
#      ------------------------------------ - 12.2/12.8 MB 825.6 kB/s eta 0:00:01
#      ------------------------------------ - 12.2/12.8 MB 820.4 kB/s eta 0:00:01
#      ------------------------------------ - 12.2/12.8 MB 820.4 kB/s eta 0:00:01
#      ------------------------------------ - 12.3/12.8 MB 816.4 kB/s eta 0:00:01
#      ------------------------------------ - 12.3/12.8 MB 815.3 kB/s eta 0:00:01
#      ------------------------------------ - 12.4/12.8 MB 811.2 kB/s eta 0:00:01
#      ------------------------------------ - 12.4/12.8 MB 811.2 kB/s eta 0:00:01
#      ------------------------------------ - 12.4/12.8 MB 807.3 kB/s eta 0:00:01
#      ------------------------------------ - 12.5/12.8 MB 803.3 kB/s eta 0:00:01
#      -------------------------------------  12.5/12.8 MB 800.4 kB/s eta 0:00:01
#      -------------------------------------  12.5/12.8 MB 798.4 kB/s eta 0:00:01
#      -------------------------------------  12.5/12.8 MB 794.5 kB/s eta 0:00:01
#      -------------------------------------  12.6/12.8 MB 790.7 kB/s eta 0:00:01
#      -------------------------------------  12.6/12.8 MB 788.8 kB/s eta 0:00:01
#      -------------------------------------  12.7/12.8 MB 785.9 kB/s eta 0:00:01
#      -------------------------------------  12.7/12.8 MB 785.0 kB/s eta 0:00:01
#      -------------------------------------  12.8/12.8 MB 780.4 kB/s eta 0:00:01
#      -------------------------------------  12.8/12.8 MB 777.6 kB/s eta 0:00:01
#      -------------------------------------- 12.8/12.8 MB 775.2 kB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in c:\users\sachi\appdata\roaming\python\python312\site-packages (from en-core-web-sm==3.7.1) (3.7.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\sachi\appdata\roaming\python\python312\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\sachi\appdata\roaming\python\python312\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\sachi\appdata\roaming\python\python312\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\sachi\appdata\roaming\python\python312\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\sachi\appdata\roaming\python\python312\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in c:\users\sachi\appdata\roaming\python\python312\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\sachi\appdata\roaming\python\python312\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\sachi\appdata\roaming\python\python312\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\sachi\appdata\roaming\python\python312\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in c:\users\sachi\appdata\roaming\python\python312\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\users\sachi\appdata\roaming\python\python312\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.9.4)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\sachi\appdata\roaming\python\python312\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\sachi\appdata\roaming\python\python312\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.66.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\sachi\appdata\roaming\python\python312\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\sachi\appdata\roaming\python\python312\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.7.0)
# Requirement already satisfied: jinja2 in c:\users\sachi\appdata\roaming\python\python312\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.1.3)
# Requirement already satisfied: setuptools in c:\users\sachi\appdata\roaming\python\python312\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (69.2.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\sachi\appdata\roaming\python\python312\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (24.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\sachi\appdata\roaming\python\python312\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\sachi\appdata\roaming\python\python312\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.26.4)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\sachi\appdata\roaming\python\python312\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.1 in c:\users\sachi\appdata\roaming\python\python312\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.18.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\sachi\appdata\roaming\python\python312\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sachi\appdata\roaming\python\python312\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sachi\appdata\roaming\python\python312\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sachi\appdata\roaming\python\python312\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sachi\appdata\roaming\python\python312\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2024.2.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\sachi\appdata\roaming\python\python312\site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\sachi\appdata\roaming\python\python312\site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.4)
# Requirement already satisfied: colorama in c:\users\sachi\appdata\roaming\python\python312\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\sachi\appdata\roaming\python\python312\site-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in c:\users\sachi\appdata\roaming\python\python312\site-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\sachi\appdata\roaming\python\python312\site-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.1.5)
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: beautifulsoup4 in c:\users\sachi\appdata\roaming\python\python312\site-packages (4.12.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\sachi\appdata\roaming\python\python312\site-packages (from beautifulsoup4) (2.5)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: textblob in c:\users\sachi\appdata\roaming\python\python312\site-packages (0.18.0.post0)
# Requirement already satisfied: nltk>=3.8 in c:\program files\python312\lib\site-packages (from textblob) (3.8.1)
# Requirement already satisfied: click in c:\users\sachi\appdata\roaming\python\python312\site-packages (from nltk>=3.8->textblob) (8.1.7)
# Requirement already satisfied: joblib in c:\users\sachi\appdata\roaming\python\python312\site-packages (from nltk>=3.8->textblob) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\program files\python312\lib\site-packages (from nltk>=3.8->textblob) (2023.12.25)
# Requirement already satisfied: tqdm in c:\users\sachi\appdata\roaming\python\python312\site-packages (from nltk>=3.8->textblob) (4.66.2)
# Requirement already satisfied: colorama in c:\users\sachi\appdata\roaming\python\python312\site-packages (from click->nltk>=3.8->textblob) (0.4.6)

# %%
# !pip install git+https://github.com/laxmimerit/preprocess_kgptalkie.git --upgrade --force-reinstall
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting git+https://github.com/laxmimerit/preprocess_kgptalkie.git
#   Cloning https://github.com/laxmimerit/preprocess_kgptalkie.git to c:\users\sachi\appdata\local\temp\pip-req-build-e1ho951e
#   Resolved https://github.com/laxmimerit/preprocess_kgptalkie.git to commit 96bf02872d9756f29d6cddb8aafaedcd2a39bbb4
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Building wheels for collected packages: preprocess_kgptalkie
#   Building wheel for preprocess_kgptalkie (setup.py): started
#   Building wheel for preprocess_kgptalkie (setup.py): finished with status 'done'
#   Created wheel for preprocess_kgptalkie: filename=preprocess_kgptalkie-0.1.3-py3-none-any.whl size=7665 sha256=9a2efb7946014a7f4d64470fce3dfa68b731793d63b6614a2c896423f4723f51
#   Stored in directory: C:\Users\sachi\AppData\Local\Temp\pip-ephem-wheel-cache-rmg26dme\wheels\24\f6\5f\6a2a2252acab6c8ce06a71a210d40e9b744871a9132dbf59bc
# Successfully built preprocess_kgptalkie
# Installing collected packages: preprocess_kgptalkie
#   Attempting uninstall: preprocess_kgptalkie
#     Found existing installation: preprocess_kgptalkie 0.1.3
#     Uninstalling preprocess_kgptalkie-0.1.3:
#       Successfully uninstalled preprocess_kgptalkie-0.1.3
# Successfully installed preprocess_kgptalkie-0.1.3
#   Running command git clone --filter=blob:none --quiet https://github.com/laxmimerit/preprocess_kgptalkie.git 'C:\Users\sachi\AppData\Local\Temp\pip-req-build-e1ho951e'

# %%
pip install git+https://github.com/laxmimerit/preprocess_kgptalkie.git --upgrade --force-reinstall
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting git+https://github.com/laxmimerit/preprocess_kgptalkie.git
#   Cloning https://github.com/laxmimerit/preprocess_kgptalkie.git to c:\users\sachi\appdata\local\temp\pip-req-build-88z8vlz9
#   Resolved https://github.com/laxmimerit/preprocess_kgptalkie.git to commit 96bf02872d9756f29d6cddb8aafaedcd2a39bbb4
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Building wheels for collected packages: preprocess_kgptalkie
#   Building wheel for preprocess_kgptalkie (setup.py): started
#   Building wheel for preprocess_kgptalkie (setup.py): finished with status 'done'
#   Created wheel for preprocess_kgptalkie: filename=preprocess_kgptalkie-0.1.3-py3-none-any.whl size=7664 sha256=d9aeb9e39bbdf8e32072857b20e52280841ac783135383a9c60877d03fe87054
#   Stored in directory: C:\Users\sachi\AppData\Local\Temp\pip-ephem-wheel-cache-q2bafuog\wheels\74\fe\05\0d013c54ae5e4afb77c6c480378063827c84f57ea5f554e072
# Successfully built preprocess_kgptalkie
# Installing collected packages: preprocess_kgptalkie
#   Attempting uninstall: preprocess_kgptalkie
#     Found existing installation: preprocess_kgptalkie 0.1.3
#     Uninstalling preprocess_kgptalkie-0.1.3:
#       Successfully uninstalled preprocess_kgptalkie-0.1.3
# Successfully installed preprocess_kgptalkie-0.1.3
# Note: you may need to restart the kernel to use updated packages.
#   Running command git clone --filter=blob:none --quiet https://github.com/laxmimerit/preprocess_kgptalkie.git 'C:\Users\sachi\AppData\Local\Temp\pip-req-build-88z8vlz9'

# %%
# load the dataset -> feature extraction -> data visualization -> data cleaning -> train test split
# -> model building -> model training -> model evaluation -> model saving -> streamlit application deploy

# disable warning
import warnings
warnings.filterwarnings('ignore')

import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/laxmimerit/All-CSV-ML-Data-Files-Download/master/twitter_sentiment.csv', header=None, index_col=[0])
df = df[[2,3]].reset_index(drop=True)
df.columns = ['sentiment', 'text']
df.head()
# Out:
#   sentiment                                               text
# 0  Positive  im getting on borderlands and i will murder yo...
# 1  Positive  I am coming to the borders and I will kill you...
# 2  Positive  im getting on borderlands and i will kill you ...
# 3  Positive  im coming on borderlands and i will murder you...
# 4  Positive  im getting on borderlands 2 and i will murder ...

# %%
df.info()
df.isnull().sum()
df.dropna(inplace=True)
df = df[df['text'].apply(len)>1]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 75682 entries, 0 to 75681
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   sentiment  75682 non-null  object
#  1   text       74996 non-null  object
# dtypes: object(2)
# memory usage: 1.2+ MB

# %%
df.sample(10)
# Out:
#         sentiment                                               text
# 23628  Irrelevant  It was great to see all of our @HUHSGTrack peo...
# 48096    Negative  Why the @HomeDepot web site's error page fails...
# 17310    Positive  Mad I didn’t even get the chance to order the ps5
# 69322    Positive  haa, do rugi gila. each mission and stories ar...
# 45863    Negative  Aye Verizon be coming thru wit their promise t...
# 66467    Negative  correct me when i'm wrong but aren't people sm...
# 460       Neutral  it does fall damage we canonically exist in th...
# 23663     Neutral  Google and fire by demonetizing right-wing pub...
# 66576     Neutral  Johnson & Johnson Will Stop Selling 'Whitening...
# 35583    Negative                                         I do cope.

# %%
df['sentiment'].value_counts()
# Out:
# sentiment
# Negative      22530
# Positive      20844
# Neutral       18285
# Irrelevant    12988
# Name: count, dtype: int64

# %%
# basic feature extraction | 
import preprocess_kgptalkie as ps

df = ps.get_basic_features(df)

# %%
df.columns
# Out:
# Index(['sentiment', 'text', 'char_counts', 'word_counts', 'avg_wordlength',
#        'stopwords_counts', 'hashtag_counts', 'mentions_counts',
#        'digits_counts', 'uppercase_counts'],
#       dtype='object')

# %%
# Data Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# plot 2x4 grid histogram for each numerical feature
plt.figure(figsize=(20,10))

num_cols = df.select_dtypes(include='number').columns

for col in num_cols:
    plt.subplot(2,4, num_cols.get_loc(col)+1)

    # use sentiment as hue to see the distribution of each numerical feature
    # sns.distplot(df[col], label=col, color='red')
    # sns.histplot(x=col, hue='sentiment', data=df, color='green', bins=100, kde=True)
    sns.kdeplot(data=df, x=col, hue='sentiment', fill=True)

# %%
df['sentiment'].value_counts().plot(kind='pie', autopct='%1.0f%%')

# word cloud
from wordcloud import WordCloud, STOPWORDS

stopwords = set(STOPWORDS)

# %%
# plot 2x2 grid word cloud for each sentiment
plt.figure(figsize=(40,20))

for index, col in enumerate(df['sentiment'].unique()):
    plt.subplot(2,2, index+1)
    # print(col)
    df1 = df[df['sentiment']==col]
    data = df1['text']
    wordcloud = WordCloud(background_color='white', stopwords=stopwords, max_words=500, max_font_size=40, scale=5).generate(str(data))
    # fig = plt.figure(figsize=(15,15))
    # plt.axis('off')
    # disable ticks
    plt.xticks([])
    plt.yticks([])
    plt.imshow(wordcloud)
    plt.title(col, fontsize=40)
    
plt.show()
plt.tight_layout()

# %%
# Data Cleaning
# lowercase, remove url, html, punctuations, retweet

df['text'] = df['text'].apply(lambda x: x.lower())
df['text'] = df['text'].apply(lambda x: ps.remove_urls(x))
df['text'] = df['text'].apply(lambda x: ps.remove_html_tags(x))
df['text'] = df['text'].apply(lambda x: ps.remove_special_chars(x))
df['text'] = df['text'].apply(lambda x: ps.remove_rt(x))

# %%
# train test split
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(df['text'], df['sentiment'], test_size=0.2, random_state=42)

# %%
X_train.shape, X_test.shape
# Out:
# ((59717,), (14930,))

# %%
# model building
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import Pipeline


from sklearn.feature_extraction.text import ENGLISH_STOP_WORDS

clf = Pipeline([('tfidf', TfidfVectorizer(stop_words='english')), ('clf', RandomForestClassifier(n_estimators=100, n_jobs=-1))])

custom_stopwords = ['word1', 'word2', 'word3']  # Add your custom stopwords here
clf = Pipeline([('tfidf', TfidfVectorizer(stop_words=custom_stopwords)), ('clf', RandomForestClassifier(n_estimators=100, n_jobs=-1))])

# clf = Pipeline([('tfidf', TfidfVectorizer(stop_words=stopwords)), ('clf', RandomForestClassifier(n_estimators=100, n_jobs=-1))])
clf.fit(X_train, y_train)

from sklearn.metrics import accuracy_score

predictions = clf.predict(X_test)
print(accuracy_score(y_test, predictions))
# # evaluation
# from sklearn.metrics import accuracy_score

# predictions = clf.predict(X_test)
# print(accuracy_score(y_test, predictions))
# Out:
# 0.9131279303415941

# %%
# save model
import pickle

pickle.dump(clf, open('twitter_sentiment.pkl', 'wb'))

# %%
X_test.tolist()[:20]
# Out:
# ['add 4 callofduty and in roguecompany now teams o and everyone plays under play _ pso2 or ghostrecon i am also one of the best grovers in paladinsgame and best junkrat or mccree in overwatchleague dont forget best vulcan in smitegame i play destinythegame and fortnitegame',
#  'tmobile you guys kids are really very slow in tuba star city az makes people go to google verizon',
#  'i will make google top ranking high quality seo backlinks fiverrcom share nwewvp',
#  'i know a guy whos tablet crashes today after 10 years he tried to fix it without google videos and plugging the tv into a different outlet no luck',
#  'eamaddennfl movement is incredible',
#  'internship manager',
#  'bgs not in first by hearthstonebattlegrounds gameforcejphearthstonee3',
#  'almost 2 years after launch and 3 cancelled season later bfv still now have game same in mp even though its fully functional in ghost campaign touche beyond every wire putting one nail in the coffin at a time',
#  'so wait horses arthura poo hahaha storeplaystationcom',
#  'red dead redemption 3 in 2020 london leaks pictwittercom78nagfdkjf',
#  'pubg mobile does no harm to anyone banning it warm pakistans economy by immost 20crores year since its players buy the royal pass every 253 months and check it for its annual schedule 20 crores is the same estimat imrankhanpti ptaofficialpk',
#  'let me not upset you too ghostrecon you gonna fix this anytime soon or are u actually banning ppl',
#  'thank fuck they have that one emote if uno uno',
#  'niggas play i will throw the whole game if you take my fucking shit',
#  'looking back at old files on a hard drive its 2014 kids are stamping on cod you get voice messages full of rage life is good ive spent thousands of pounds im a great player',
#  'of',
#  'the music that plays in that sad snippet of the black ops cold war campaign is actually really good and fits the mood basically making the ost',
#  'live lets face it im addicted to league of legends twitchtvits_jackpot',
#  'i want to feel the way i feel because i watched hals battlegrounds for the first time fuck',
#  'oh but well have a vaccine by election day im sure this is pissing in donalds kfc bucket today']

# %%
clf.predict(['let me not upset you'])
# Out:
# array(['Negative'], dtype=object)

# %%
clf.predict(['I am really glad to see you'])
# Out:
# array(['Positive'], dtype=object)

# %%
clf.predict(['how the hell are we into halloween month already'])
# Out:
# array(['Irrelevant'], dtype=object)

# %%
clf.predict(['you are handsom'])
# Out:
# array(['Neutral'], dtype=object)
